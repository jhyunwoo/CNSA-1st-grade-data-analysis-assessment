# %%
# 파이썬 시각화 패키지 불러오기
import matplotlib.pyplot as plt
# %matplotlib inline


# 사용자 운영체제 확인
import platform
platform.system()

# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

import csv
import matplotlib.pyplot as plt
money1 = open("경기도 의정부시_지역화폐 업종별 사용금액_20211121.csv")
data1 = csv.reader(money1)

#시군명, 기준년, 업종명(대분류), 업종코드, 세부업종, 카드사용액, 데이터기준일자

name = "일반휴게음식"
result = []
store = []


for row1 in data1:
    for i in row1[2:3]:
        if i not in store:
            store.append(str(i))


var_1 = 0
var_2 = 0
var_3 = 0
var_4 = 0
var_5 = 0
var_6 = 0
var_7 = 0
var_8 = 0
var_9 = 0
var_10 = 0
var_11 = 0
var_12 = 0
var_13 = 0
var_14 = 0
var_15 = 0
var_16 = 0
var_17 = 0
var_18 = 0
var_19 = 0
var_20 = 0
var_21 = 0
var_22 = 0
var_23 = 0
var_24 = 0
var_25 = 0
var_26 = 0
var_27 = 0
var_28 = 0
var_29 = 0
var_30 = 0
var_31 = 0
var_32 = 0
var_33 = 0
var_34 = 0
var_35 = 0
var_36 = 0

money2 = open("경기도 의정부시_지역화폐 업종별 사용금액_20211121.csv")
data2 = csv.reader(money2)

for row in data2:
    if "일반휴게음식" == row[2]:
        for i in row[5:6]:
            var_1 = var_1 + int(i)
    elif store[1] in row[2]:
        for i in row[5:6]:
            var_2 = var_2 + int(i)
    elif store[2] in row[2]:
        for i in row[5:6]:
            var_3 = var_3 + int(i)
    elif store[3] in row[2]:
        for i in row[5:6]:
            var_4 = var_4 + int(i)
    elif store[4] in row[2]:
        for i in row[5:6]:
            var_5 = var_5 + int(i)
    elif store[5] in row[2]:
        for i in row[5:6]:
            var_6 = var_6 + int(i)
    elif store[6] in row[2]:
        for i in row[5:6]:
            var_7 = var_7 + int(i)
    elif store[7] in row[2]:
        for i in row[5:6]:
            var_8 = var_8 + int(i)
    elif store[8] in row[2]:
        for i in row[5:6]:
            var_9 = var_9 + int(i)
    elif store[9] in row[2]:
        for i in row[5:6]:
            var_10 = var_10 + int(i)
    elif store[10] in row[2]:
        for i in row[5:6]:
            var_11 = var_11 + int(i)
    elif store[11] in row[2]:
        for i in row[5:6]:
            var_12 = var_12 + int(i)
    elif store[12] in row[2]:
        for i in row[5:6]:
            var_13 = var_13 + int(i)
    elif store[13] in row[2]:
        for i in row[5:6]:
            var_14 = var_14 + int(i)
    elif store[14] in row[2]:
        for i in row[5:6]:
            var_15 = var_15 + int(i)
    elif store[15] in row[2]:
        for i in row[5:6]:
            var_16 = var_16 + int(i)
    elif store[16] in row[2]:
        for i in row[5:6]:
            var_17 = var_17 + int(i)
    elif store[17] in row[2]:
        for i in row[5:6]:
            var_18 = var_18 + int(i)
    elif store[18] in row[2]:
        for i in row[5:6]:
            var_19 = var_19 + int(i)
    elif store[19] in row[2]:
        for i in row[5:6]:
            var_20 = var_20 + int(i)
    elif store[20] in row[2]:
        for i in row[5:6]:
            var_21 = var_21 + int(i)
    elif store[21] in row[2]:
        for i in row[5:6]:
            var_22 = var_22 + int(i)
    elif store[22] in row[2]:
        for i in row[5:6]:
            var_23 = var_23 + int(i)
    elif store[23] in row[2]:
        for i in row[5:6]:
            var_24 = var_24 + int(i)
    elif store[24] in row[2]:
        for i in row[5:6]:
            var_25 = var_25 + int(i)
    elif store[25] in row[2]:
        for i in row[5:6]:
            var_26 = var_26 + int(i)
    elif store[26] in row[2]:
        for i in row[5:6]:
            var_27 = var_27 + int(i)
    elif store[27] in row[2]:
        for i in row[5:6]:
            var_28 = var_28 + int(i)
    elif store[28] in row[2]:
        for i in row[5:6]:
            var_29 = var_29 + int(i)
    elif store[29] in row[2]:
        for i in row[5:6]:
            var_30 = var_30 + int(i)
    elif store[30] in row[2]:
        for i in row[5:6]:
            var_31 = var_31 + int(i)
    elif store[31] in row[2]:
        for i in row[5:6]:
            var_32 = var_32 + int(i)
    elif store[32] in row[2]:
        for i in row[5:6]:
            var_33 = var_33 + int(i)
    elif store[33] in row[2]:
        for i in row[5:6]:
            var_34 = var_34 + int(i)
    elif store[34] in row[2]:
        for i in row[5:6]:
            var_35 = var_35 + int(i)
    elif store[35] in row[2]:
        for i in row[5:6]:
            var_36 = var_36 + int(i)
result.append(var_1)
result.append(var_2)
result.append(var_3)
result.append(var_4)
result.append(var_5)
result.append(var_6)
result.append(var_7)
result.append(var_8)
result.append(var_9)
result.append(var_10)
result.append(var_11)
result.append(var_12)
result.append(var_13)
result.append(var_14)
result.append(var_15)
result.append(var_16)
result.append(var_17)
result.append(var_18)
result.append(var_19)
result.append(var_20)
result.append(var_21)
result.append(var_22)
result.append(var_23)
result.append(var_24)
result.append(var_25)
result.append(var_26)
result.append(var_27)
result.append(var_28)
result.append(var_29)
result.append(var_30)
result.append(var_31)
result.append(var_32)
result.append(var_33)
result.append(var_34)
result.append(var_35)
result.append(var_36)

plt.figure(figsize=(50,5), dpi=800)
plt.bar(store, result, color = "blue")
plt.title("경기도 의정부시 지역화폐 업종별 사용 금액")
plt.xlabel("업종")
plt.ylabel("금액(\)")
plt.show()
